# %%
import numpy as np
import pandas as pd
covid = pd.read_csv("/Users/mansipandya/Desktop/us-counties.csv")
covid
# Out:
#            date      county       state     fips  cases  deaths
# 0       1/21/20   Snohomish  Washington  53061.0      1       0
# 1       1/22/20   Snohomish  Washington  53061.0      1       0
# 2       1/23/20   Snohomish  Washington  53061.0      1       0
# 3       1/24/20        Cook    Illinois  17031.0      1       0
# 4       1/24/20   Snohomish  Washington  53061.0      1       0
# ...         ...         ...         ...      ...    ...     ...
# 337563  7/15/20  Sweetwater     Wyoming  56037.0    157       1
# 337564  7/15/20       Teton     Wyoming  56039.0    170       1
# 337565  7/15/20       Uinta     Wyoming  56041.0    208       0
# 337566  7/15/20    Washakie     Wyoming  56043.0     42       5
# 337567  7/15/20      Weston     Wyoming  56045.0      3       0
#
# [337568 rows x 6 columns]

# %%
covid.head()
# Out:
#       date     county       state     fips  cases  deaths
# 0  1/21/20  Snohomish  Washington  53061.0      1       0
# 1  1/22/20  Snohomish  Washington  53061.0      1       0
# 2  1/23/20  Snohomish  Washington  53061.0      1       0
# 3  1/24/20       Cook    Illinois  17031.0      1       0
# 4  1/24/20  Snohomish  Washington  53061.0      1       0

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337568 entries, 0 to 337567
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    337568 non-null  object
#  1   county  337568 non-null  object
#  2   state   337568 non-null  object
#  3   fips    334129 non-null  float64
#  4   cases   337568 non-null  int64
#  5   deaths  337568 non-null  int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 15.5+ MB

# %%
pop = pd.read_excel('/Users/mansipandya/Desktop/co-est2019-alldata.xls')
pop
# Out:
#         State             County                     Geographic Area   Census  \
# 0     Alabama            Alabama                   Alabama , Alabama  4779736
# 1     Alabama     Autauga County  Autauga County , Alabama , Alabama    54571
# 2     Alabama     Baldwin County            Baldwin County , Alabama   182265
# 3     Alabama     Barbour County            Barbour County , Alabama    27457
# 4     Alabama        Bibb County               Bibb County , Alabama    22915
# ...       ...                ...                                 ...      ...
# 3188  Wyoming  Sweetwater County         Sweetwater County , Wyoming    43806
# 3189  Wyoming       Teton County              Teton County , Wyoming    21294
# 3190  Wyoming       Uinta County              Uinta County , Wyoming    21118
# 3191  Wyoming    Washakie County           Washakie County , Wyoming     8533
# 3192  Wyoming      Weston County             Weston County , Wyoming     7208
#
# ...

# %%
pop.head()
# Out:
#      State          County                     Geographic Area   Census  \
# 0  Alabama         Alabama                   Alabama , Alabama  4779736
# 1  Alabama  Autauga County  Autauga County , Alabama , Alabama    54571
# 2  Alabama  Baldwin County            Baldwin County , Alabama   182265
# 3  Alabama  Barbour County            Barbour County , Alabama    27457
# 4  Alabama     Bibb County               Bibb County , Alabama    22915
#
#    Estimates Base  Population Estimate 2010  Population Estimate 2011  \
# 0         4780125                   4785437                   4799069
# 1           54597                     54773                     55227
# 2          182265                    183112                    186558
# 3           27455                     27327                     27341
# 4           22915                     22870                     22745
#
#    Population Estimate 2012  Population Estimate 2013  \
# ...

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3193 entries, 0 to 3192
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   State                     3193 non-null   object
#  1   County                    3193 non-null   object
#  2   Geographic Area           3193 non-null   object
#  3   Census                    3193 non-null   int64
#  4   Estimates Base            3193 non-null   int64
#  5   Population Estimate 2010  3193 non-null   int64
#  6   Population Estimate 2011  3193 non-null   int64
#  7   Population Estimate 2012  3193 non-null   int64
#  8   Population Estimate 2013  3193 non-null   int64
#  9   Population Estimate 2014  3193 non-null   int64
#  10  Population Estimate 2015  3193 non-null   int64
#  11  Population Estimate 2016  3193 non-null   int64
#  12  Population Estimate 2017  3193 non-null   int64
#  13  Population Estimate 2018  3193 non-null   int64
# ...

# %%
pop = pop.drop(["Estimates Base"], axis=1)
pop
# Out:
#         State             County                     Geographic Area   Census  \
# 0     Alabama            Alabama                   Alabama , Alabama  4779736
# 1     Alabama     Autauga County  Autauga County , Alabama , Alabama    54571
# 2     Alabama     Baldwin County            Baldwin County , Alabama   182265
# 3     Alabama     Barbour County            Barbour County , Alabama    27457
# 4     Alabama        Bibb County               Bibb County , Alabama    22915
# ...       ...                ...                                 ...      ...
# 3188  Wyoming  Sweetwater County         Sweetwater County , Wyoming    43806
# 3189  Wyoming       Teton County              Teton County , Wyoming    21294
# 3190  Wyoming       Uinta County              Uinta County , Wyoming    21118
# 3191  Wyoming    Washakie County           Washakie County , Wyoming     8533
# 3192  Wyoming      Weston County             Weston County , Wyoming     7208
#
# ...

# %%
pop = pop.drop(["Population Estimate 2010", "Population Estimate 2011", "Population Estimate 2012", "Population Estimate 2013", "Population Estimate 2014", "Population Estimate 2015", "Population Estimate 2016", "Population Estimate 2017", "Population Estimate 2018"], axis=1)
pop
# Out:
#         State             County                     Geographic Area   Census  \
# 0     Alabama            Alabama                   Alabama , Alabama  4779736
# 1     Alabama     Autauga County  Autauga County , Alabama , Alabama    54571
# 2     Alabama     Baldwin County            Baldwin County , Alabama   182265
# 3     Alabama     Barbour County            Barbour County , Alabama    27457
# 4     Alabama        Bibb County               Bibb County , Alabama    22915
# ...       ...                ...                                 ...      ...
# 3188  Wyoming  Sweetwater County         Sweetwater County , Wyoming    43806
# 3189  Wyoming       Teton County              Teton County , Wyoming    21294
# 3190  Wyoming       Uinta County              Uinta County , Wyoming    21118
# 3191  Wyoming    Washakie County           Washakie County , Wyoming     8533
# 3192  Wyoming      Weston County             Weston County , Wyoming     7208
#
#       Population Estimate 2019
# ...

# %%
pop = pop.drop(["Census"], axis=1)
pop
# Out:
#         State             County                     Geographic Area  \
# 0     Alabama            Alabama                   Alabama , Alabama
# 1     Alabama     Autauga County  Autauga County , Alabama , Alabama
# 2     Alabama     Baldwin County            Baldwin County , Alabama
# 3     Alabama     Barbour County            Barbour County , Alabama
# 4     Alabama        Bibb County               Bibb County , Alabama
# ...       ...                ...                                 ...
# 3188  Wyoming  Sweetwater County         Sweetwater County , Wyoming
# 3189  Wyoming       Teton County              Teton County , Wyoming
# 3190  Wyoming       Uinta County              Uinta County , Wyoming
# 3191  Wyoming    Washakie County           Washakie County , Wyoming
# 3192  Wyoming      Weston County             Weston County , Wyoming
#
#       Population Estimate 2019
# 0                      4903185
# 1                        55869
# 2                       223234
# ...

# %%
pop = pop[['Geographic Area','Population Estimate 2019']][0:3194]
pop.tail(10)
# Out:
#                   Geographic Area  Population Estimate 2019
# 3183    Niobrara County , Wyoming                      2356
# 3184        Park County , Wyoming                     29194
# 3185      Platte County , Wyoming                      8393
# 3186    Sheridan County , Wyoming                     30485
# 3187    Sublette County , Wyoming                      9831
# 3188  Sweetwater County , Wyoming                     42343
# 3189       Teton County , Wyoming                     23464
# 3190       Uinta County , Wyoming                     20226
# 3191    Washakie County , Wyoming                      7805
# 3192      Weston County , Wyoming                      6927

# %%
pop['County'] = pop['Geographic Area'].apply(lambda x: x.split(', ')[0][0:])
pop['County'] = pop['County'].apply(lambda x: x.split(' County')[0])
pop['County'] = pop['County'].apply(lambda x: x.split(' Parish')[0]) # for LA
pop['County'] = pop['County'].apply(lambda x: x.split(' City')[0]) # for VA
pop['State'] = pop['Geographic Area'].apply(lambda x: x.split(', ')[1])
#pop['State'] = pop['State'].apply(lambda x: x.split('State')[0])
pop.head(70)
# Out:
#                        Geographic Area  Population Estimate 2019  \
# 0                    Alabama , Alabama                   4903185
# 1   Autauga County , Alabama , Alabama                     55869
# 2             Baldwin County , Alabama                    223234
# 3             Barbour County , Alabama                     24686
# 4                Bibb County , Alabama                     22394
# ..                                 ...                       ...
# 65         Washington County , Alabama                     16326
# 66             Wilcox County , Alabama                     10373
# 67            Winston County , Alabama                     23629
# 68                     Alaska , Alaska                    731545
# 69     Aleutians East Borough , Alaska                      3337
#
#                      County     State
# 0                  Alabama    Alabama
# 1                   Autauga  Alabama
# 2                   Baldwin   Alabama
# ...

# %%
pop[pop['State']=='Alaska']
# Out:
#                                Geographic Area  Population Estimate 2019  \
# 68                             Alaska , Alaska                    731545
# 69             Aleutians East Borough , Alaska                      3337
# 70         Aleutians West Census Area , Alaska                      5634
# 71             Anchorage Municipality , Alaska                    288000
# 72                 Bethel Census Area , Alaska                     18386
# 73                Bristol Bay Borough , Alaska                       836
# 74                     Denali Borough , Alaska                      2097
# 75             Dillingham Census Area , Alaska                      4916
# 76       Fairbanks North Star Borough , Alaska                     96849
# 77                     Haines Borough , Alaska                      2530
# 78          Hoonah-Angoon Census Area , Alaska                      2148
# 79            Juneau City and Borough , Alaska                     31974
# ...

# %%
pop[pop['State']=='Louisiana']
# Out:
#                           Geographic Area  Population Estimate 2019  \
# 1131                Louisiana , Louisiana                   4648794
# 1132            Acadia Parish , Louisiana                     62045
# 1133             Allen Parish , Louisiana                     25627
# 1134         Ascension Parish , Louisiana                    126604
# 1135        Assumption Parish , Louisiana                     21891
# ...                                   ...                       ...
# 1191           Webster Parish , Louisiana                     38340
# 1192  West Baton Rouge Parish , Louisiana                     26465
# 1193      West Carroll Parish , Louisiana                     10830
# 1194    West Feliciana Parish , Louisiana                     15568
# 1195              Winn Parish , Louisiana                     13904
#
#                 County      State
# 1131        Louisiana   Louisiana
# 1132            Acadia  Louisiana
# 1133             Allen  Louisiana
# ...

# %%
#covid[covid['county']=='New York City']['county'] = 'New York'
#covid[covid['county']=='New York City']['county'].apply(lambda x: x.split(' '))
covid.loc[covid['county'] == 'New York City','county'] = 'New York'
covid[covid['state']=='New York']
# Out:
#            date       county     state     fips  cases  deaths
# 416      3/1/20     New York  New York      NaN      1       0
# 448      3/2/20     New York  New York      NaN      1       0
# 482      3/3/20     New York  New York      NaN      2       0
# 518      3/4/20     New York  New York      NaN      2       0
# 519      3/4/20  Westchester  New York  36119.0      9       0
# ...         ...          ...       ...      ...    ...     ...
# 336236  7/15/20   Washington  New York  36115.0    250      11
# 336237  7/15/20        Wayne  New York  36117.0    221       1
# 336238  7/15/20  Westchester  New York  36119.0  35393    1568
# 336239  7/15/20      Wyoming  New York  36121.0    103       3
# 336240  7/15/20        Yates  New York  36123.0     50       6
#
# [7006 rows x 6 columns]

# %%
df = pd.merge(covid,pop,left_on=['county','state'],right_on=['County','State'],how='inner')
df
# Out:
#            date       county       state     fips  cases  deaths  \
# 0       1/21/20    Snohomish  Washington  53061.0      1       0
# 1       1/22/20    Snohomish  Washington  53061.0      1       0
# 2       1/23/20    Snohomish  Washington  53061.0      1       0
# 3       1/24/20    Snohomish  Washington  53061.0      1       0
# 4       1/25/20    Snohomish  Washington  53061.0      1       0
# ...         ...          ...         ...      ...    ...     ...
# 321652  7/14/20         Kent       Texas  48263.0      1       0
# 321653  7/15/20         Kent       Texas  48263.0      1       0
# 321654  7/14/20     McMullen       Texas  48311.0      1       0
# 321655  7/15/20     McMullen       Texas  48311.0      1       0
# 321656  7/15/20  Sweet Grass     Montana  30097.0      1       0
#
#                       Geographic Area  Population Estimate 2019       County  \
# 0       Snohomish County , Washington                    822083    Snohomish
# ...

# %%
df.columns
# Out:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths', 'Geographic Area',
#        'Population Estimate 2019', 'County', 'State'],
#       dtype='object')

# %%
dfm = df[['date','County','State','cases','deaths','Population Estimate 2019']]

# %%
dfm
# Out:
#            date       County       State  cases  deaths  \
# 0       1/21/20    Snohomish  Washington      1       0
# 1       1/22/20    Snohomish  Washington      1       0
# 2       1/23/20    Snohomish  Washington      1       0
# 3       1/24/20    Snohomish  Washington      1       0
# 4       1/25/20    Snohomish  Washington      1       0
# ...         ...          ...         ...    ...     ...
# 321652  7/14/20         Kent       Texas      1       0
# 321653  7/15/20         Kent       Texas      1       0
# 321654  7/14/20     McMullen       Texas      1       0
# 321655  7/15/20     McMullen       Texas      1       0
# 321656  7/15/20  Sweet Grass     Montana      1       0
#
#         Population Estimate 2019
# 0                         822083
# 1                         822083
# 2                         822083
# 3                         822083
# 4                         822083
# ...                          ...
# 321652                       762
# ...

# %%
dfm.to_excel('covid-as-per-us-county-population.xlsx')

# %%
dfm.head()
# Out:
#       date     County       State  cases  deaths  Population Estimate 2019
# 0  1/21/20  Snohomish  Washington      1       0                    822083
# 1  1/22/20  Snohomish  Washington      1       0                    822083
# 2  1/23/20  Snohomish  Washington      1       0                    822083
# 3  1/24/20  Snohomish  Washington      1       0                    822083
# 4  1/25/20  Snohomish  Washington      1       0                    822083

# %%
dfdate = dfm[dfm['date']=='7/15/20'] #till 15th july
np.percentile(dfdate['cases'],80)
# Out:
# 675.0

# %%
np.percentile(dfdate['deaths'],80)
# Out:
# 17.0
